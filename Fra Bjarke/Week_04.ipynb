# %%
import numpy as np
import matplotlib.pyplot as plt
import asp_func as f

# %% [markdown]
# # Functions

# %% [markdown]
# # Problems From Multirate Problems PDF

# %% [markdown]
# ### Problem 14

# %% [markdown]
# ![image.png](attachment:d37e766f-4249-480e-b19f-ddc5ee86ba88.png)

# %% [markdown]
# ### Problem 15

# %% [markdown]
# ![image.png](attachment:99db5f6b-2566-46aa-9ddf-7ff5b32f0ef6.png)

# %% [markdown]
# # Problems from Random Signal Problems PDF

# %% [markdown]
# ### Problem 1

# %% [markdown]
# ![image.png](attachment:a6ff7787-aa93-49ba-83fb-8439848191ff.png)

# %% [markdown]
# ### Problem 2

# %% [markdown]
# ![image.png](attachment:cb3b3c80-e166-4370-b81b-9483db0b0529.png)

# %% [markdown]
# ### Problem 3

# %% [markdown]
# ![image.png](attachment:c2789e4d-770e-49b8-baec-d85bff829299.png)

# %% [markdown]
# ### Problem 4

# %% [markdown]
# ![image.png](attachment:8889b10e-ebe5-49b2-a9f6-9eaea3f271f9.png)

# %% [markdown]
# ### Problem 5

# %% [markdown]
# ![image.png](attachment:5fdc5602-68b4-4db3-bc84-d2f0f86e8ba9.png)

# %% [markdown]
# ### Problem 6

# %% [markdown]
# ![image.png](attachment:2633ce69-a972-45aa-92a8-225a5645f396.png)

# %% [markdown]
# ### Problem 7

# %% [markdown]
# ![image.png](attachment:6e64f177-6b03-40d9-9e71-e13a135f087e.png)

# %% [markdown]
# ### Problem 8

# %% [markdown]
# ![image.png](attachment:75e35143-2d83-4c09-b8ae-661c3189ec36.png)

# %% [markdown]
# ### Problem 9

# %% [markdown]
# ![image.png](attachment:c3c7e808-7c7b-4f8a-91c6-8bf4be429fe6.png)
